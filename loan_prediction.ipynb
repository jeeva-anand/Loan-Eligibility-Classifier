# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Paste the path you copied from the file browser
test = '/content/drive/MyDrive/Colab Notebooks/Loan Prediction /test_lAUu6dG.csv'
train = '/content/drive/MyDrive/Colab Notebooks/Loan Prediction /train_ctrUa4K.csv'

test = pd.read_csv(test)
train = pd.read_csv(train)

# %%
train = train.copy()
test = test.copy()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train.describe(include="object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP002990   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

arr = pd.DataFrame(np.array([1,11, 12, 14, 15, 18, 100]))


arr.boxplot()

arr.plot.box()
# Out:
# <Axes: >

# %%
(train['Loan_Status'].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
(train['Loan_Status'].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
plt.figure(1,figsize=(10,5))

# plt.subplot(221,)
# temp = train['Gender'].value_counts(normalize=True)*100

# plt.bar(temp.index,temp.values,)

plt.subplot(221)
(train['Gender'].value_counts(normalize=True)*100).plot.bar()


plt.subplot(222)
(train['Married'].value_counts(normalize=True)*100).plot.bar(title="")

plt.subplot(223)
(train['Self_Employed'].value_counts(normalize=True)*100).plot.bar(title="")

plt.subplot(224)
(train['Credit_History'].value_counts(normalize=True)*100).plot.bar(title="")

plt.show()

# %%
plt.figure(2)

plt.subplot(131)
(train['Dependents'].value_counts(normalize=True)*100).plot.bar(figsize=(24,6))

plt.subplot(132)
(train['Education'].value_counts(normalize=True)*100).plot.bar()

plt.subplot(133)
(train['Property_Area'].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: xlabel='Property_Area'>

# %%
import seaborn as sns


plt.figure(1,figsize=(16,5))

plt.subplot(131)
sns.distplot(train['ApplicantIncome'])

plt.subplot(132)
train['ApplicantIncome'].plot.box()

plt.subplot(133)
train['ApplicantIncome'].plot.hist()
# Out:
# /tmp/ipykernel_3391/3779427874.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['ApplicantIncome'])
# <Axes: ylabel='Frequency'>

# %%
train.boxplot(column="ApplicantIncome", by="Education")
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education'>

# %%
plt.subplot(121)
sns.distplot(train['CoapplicantIncome'])

plt.subplot(122)
train['CoapplicantIncome'].plot.box(figsize=(16,5))
# Out:
# /tmp/ipykernel_3391/844436244.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['CoapplicantIncome'])
# <Axes: >

# %%
plt.subplot(121)
sns.distplot(train['LoanAmount'])

plt.subplot(122)
train['LoanAmount'].plot.box(figsize=(16,5))
# Out:
# /tmp/ipykernel_3391/4122249697.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['LoanAmount'])
# <Axes: >

# %%
Gender = pd.crosstab(train['Gender'],train['Loan_Status'])
Gender
# Out:
# Loan_Status    N    Y
# Gender
# Female        37   75
# Male         150  339

# %%
Gender.sum(axis=1).astype(float)
# Out:
# Gender
# Female    112.0
# Male      489.0
# dtype: float64

# %%
Gender.div(Gender.sum(axis=1).astype(float),axis=0)
# Out:
# Loan_Status         N         Y
# Gender
# Female       0.330357  0.669643
# Male         0.306748  0.693252

# %%
(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Gender'>

# %%
from matplotlib import axes

plt.subplot(221)
(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar",stacked=True)


married = pd.crosstab(train['Married'],train['Loan_Status'])
plt.subplot(222)
(married.div(married.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True)


dependents = pd.crosstab(train['Dependents'],train['Loan_Status'])
plt.subplot(223)
(dependents.div(dependents.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True)


education = pd.crosstab(train['Education'],train['Loan_Status'])
plt.subplot(224)
(education.div(education.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='Education'>

# %%
fig, ax = plt.subplots(2,2)
fig.set_size_inches(12, 10)
fig.suptitle("Loan Data Analysis")


(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[0,0])


married = pd.crosstab(train['Married'],train['Loan_Status'])

(married.div(married.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[0,1])


dependents = pd.crosstab(train['Dependents'],train['Loan_Status'])

(dependents.div(dependents.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[1,0])


education = pd.crosstab(train['Education'],train['Loan_Status'])

(education.div(education.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[1,1])
# Out:
# <Axes: xlabel='Education'>

# %%
married = train.groupby(['Married','Loan_Status']).size().unstack()
married
# Out:
# Loan_Status    N    Y
# Married
# No            79  134
# Yes          113  285

# %%
# Numerical vs Target Variable

train.groupby('Loan_Status')["ApplicantIncome"].mean().plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
bins=[0,2500,4000,6000,81000]
group = ['Low','Average','High','Very High']
train['Income_bin'] = pd.cut(train['ApplicantIncome'],bins,labels=group)

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status Income_bin
# 0             1.0         Urban           Y       High
# 1             1.0         Rural           N       High
# 2             1.0         Urban           Y    Average
# 3             1.0         Urban           Y    Average
# 4             1.0         Urban           Y       High

# %%
train['Income_bin'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Income_bin'>

# %%
Income_bin = pd.crosstab(train['Income_bin'],train['Loan_Status'])
Income_bin = (Income_bin.div(Income_bin.sum(1),axis=0)*100).plot(kind="bar",stacked=True)

Income_bin
# Out:
# <Axes: xlabel='Income_bin'>

# %%
bins = [0,1000,2000,3000,42000]
groups = ['low','medium','high','very high']

train['coApplicantBin'] = pd.cut(train['CoapplicantIncome'],bins,labels=groups)


coApplicantBin = train.groupby([train['coApplicantBin'],train['Loan_Status']]).size().unstack()

coApplicantBin = coApplicantBin.div(coApplicantBin.sum(1).astype(float),axis=0)*100

coApplicantBin

coApplicantBin.plot.bar(stacked=True)
# Out:
# /tmp/ipykernel_3391/953650153.py:7: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   coApplicantBin = train.groupby([train['coApplicantBin'],train['Loan_Status']]).size().unstack()
# <Axes: xlabel='coApplicantBin'>

# %%
train["total_Income"] = train['ApplicantIncome'] + train['CoapplicantIncome']
bins = [0,2500,4000,6000,81000]
group1 = ['low','medium','high','very high']

train['total_Income_bin'] = pd.cut(train['total_Income'],bins,labels=group1)

train.head()



total_Income_bin = pd.crosstab(train['total_Income_bin'],train['Loan_Status'])


# total_Income_bin.div(total_Income_bin.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True)

total_Income_bin = total_Income_bin.div(total_Income_bin.sum(1).astype(float),axis=0)*100

total_Income_bin


total_Income_bin.plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='total_Income_bin'>

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status Income_bin coApplicantBin  \
# 0             1.0         Urban           Y       High            NaN
# 1             1.0         Rural           N       High         medium
# 2             1.0         Urban           Y    Average            NaN
# 3             1.0         Urban           Y    Average           high
# 4             1.0         Urban           Y       High            NaN
#
#    total_Income total_Income_bin
# 0        5849.0             high
# 1        6091.0        very high
# 2        3000.0           medium
# 3        4941.0             high
# 4        6000.0             high

# %%
bins = [0,100,200,700]
groups = ['low','average','high']

train['LoanAmount_bin'] = pd.cut(train['LoanAmount'],bins,labels=groups)

LoanAmount_bin = pd.crosstab(train['LoanAmount_bin'],train['Loan_Status'])

LoanAmount_bin.div(LoanAmount_bin.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True)
# Out:
# <Axes: xlabel='LoanAmount_bin'>

# %%
train = train.drop(columns=["LoanAmount_bin"])

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status Income_bin coApplicantBin  \
# 0             1.0         Urban           Y       High            NaN
# 1             1.0         Rural           N       High         medium
# 2             1.0         Urban           Y    Average            NaN
# 3             1.0         Urban           Y    Average           high
# 4             1.0         Urban           Y       High            NaN
#
#    total_Income total_Income_bin
# 0        5849.0             high
# 1        6091.0        very high
# 2        3000.0           medium
# 3        4941.0             high
# 4        6000.0             high

# %%
train['Dependents'].replace("3+",3,inplace=True)
test['Dependents'].replace("3+",3,inplace=True)

train["Loan_Status"].replace('N',0,inplace=True)
train["Loan_Status"].replace('Y',1,inplace=True)


train["Gender"].replace('Male',1,inplace=True)
train["Gender"].replace('Female',0,inplace=True)

train['Married'].replace('Yes',1,inplace=True)
train['Married'].replace('No',0,inplace=True)

train['Education'].replace('Graduate',1,inplace=True)
train['Education'].replace('Not Graduate',0,inplace=True)


train["Property_Area"].replace("Urban",1,inplace=True)
train["Property_Area"].replace("Rural",0,inplace=True)
train["Property_Area"].replace("Semiurban",2,inplace=True)


train["Self_Employed"].replace("Yes",1,inplace=True)
train["Self_Employed"].replace("No",0,inplace=True)
# Out:
# /tmp/ipykernel_3391/746814750.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Dependents'].replace("3+",3,inplace=True)
# /tmp/ipykernel_3391/746814750.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test['Dependents'].replace("3+",3,inplace=True)
# /tmp/ipykernel_3391/746814750.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train["Loan_Status"].replace('N',0,inplace=True)
# /tmp/ipykernel_3391/746814750.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train["Loan_Status"].replace('Y',1,inplace=True)
# /tmp/ipykernel_3391/746814750.py:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Married'].replace('Yes',1,inplace=True)
# /tmp/ipykernel_3391/746814750.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Married'].replace('No',0,inplace=True)
# /tmp/ipykernel_3391/746814750.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Education'].replace('Graduate',1,inplace=True)
# /tmp/ipykernel_3391/746814750.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train['Education'].replace('Not Graduate',0,inplace=True)
# /tmp/ipykernel_3391/746814750.py:20: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   train["Property_Area"].replace("Semiurban",2,inplace=True)

# %%
train = train.drop('Loan_ID',axis=1)

# %%
train = train.drop(columns=['coApplicantBin','Income_bin',"total_Income_bin"])

# %%
train.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0     1.0      0.0          0          1            0.0             5849
# 1     1.0      1.0          1          1            0.0             4583
# 2     1.0      1.0          0          1            1.0             3000
# 3     1.0      1.0          0          0            0.0             2583
# 4     1.0      0.0          0          1            0.0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area  Loan_Status  total_Income
# 0             1            1        5849.0
# 1             0            0        6091.0
# 2             1            1        3000.0
# 3             1            1        4941.0
# 4             1            1        6000.0

# %%
mat = train.corr()
fig, ax = plt.subplots(figsize=(9,6))
sns.heatmap(mat,vmax= .8, square = True, cmap = "BuPu")
# Out:
# <Axes: >
