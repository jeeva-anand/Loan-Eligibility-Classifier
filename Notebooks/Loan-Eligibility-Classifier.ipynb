# %%
import sys
from pathlib import Path


PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

# Paste the path you copied from the file browser
test_data = '../data/train_ctrUa4K.csv'
train_data = '../data/test_lAUu6dG.csv'



test_cp = pd.read_csv(test_data)
train_cp = pd.read_csv(train_data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import pandas as pd
#       2
#       3 # Paste the path you copied from the file browser
#       4 test_data = '../data/train_ctrUa4K.csv'
#
# ModuleNotFoundError: No module named 'pandas'

# %%
test_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
train = train_cp.copy()
test = test_cp.copy()

# %%
train.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
train.describe(include="object")
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP002990   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
train.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
train.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# arr = pd.DataFrame(np.array([1,11, 12, 14, 15, 18, 100]))

arr = train['LoanAmount'].plot.box()


# arr.boxplot()

# arr.plot.box()

# %%
(train['Loan_Status'].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
(train['Loan_Status'].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
plt.figure(1,figsize=(10,5))

# plt.subplot(221,)
# temp = train['Gender'].value_counts(normalize=True)*100

# plt.bar(temp.index,temp.values,)

plt.subplot(221)
(train['Gender'].value_counts(normalize=True)*100).plot.bar()


plt.subplot(222)
(train['Married'].value_counts(normalize=True)*100).plot.bar(title="")

plt.subplot(223)
(train['Self_Employed'].value_counts(normalize=True)*100).plot.bar(title="")

plt.subplot(224)
(train['Credit_History'].value_counts(normalize=True)*100).plot.bar(title="")

plt.show()

# %%
plt.figure(2)

plt.subplot(131)
(train['Dependents'].value_counts(normalize=True)*100).plot.bar(figsize=(24,6))

plt.subplot(132)
(train['Education'].value_counts(normalize=True)*100).plot.bar()

plt.subplot(133)
(train['Property_Area'].value_counts(normalize=True)*100).plot.bar()
# Out:
# <Axes: xlabel='Property_Area'>

# %%
import seaborn as sns


plt.figure(1,figsize=(16,5))

plt.subplot(131)
sns.distplot(train['ApplicantIncome'])

plt.subplot(132)
train['ApplicantIncome'].plot.box()

plt.subplot(133)
train['ApplicantIncome'].plot.hist()
# Out:
# /tmp/ipykernel_703/3779427874.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['ApplicantIncome'])
# <Axes: ylabel='Frequency'>

# %%
train.boxplot(column="ApplicantIncome", by="Education")

# train.boxplot(column="Education", by="ApplicantIncome")
# Out:
# <Axes: title={'center': 'ApplicantIncome'}, xlabel='Education'>

# %%
plt.subplot(121)
sns.distplot(train['CoapplicantIncome'])

plt.subplot(122)
train['CoapplicantIncome'].plot.box(figsize=(16,5))

# %%
plt.subplot(121)
sns.distplot(train['LoanAmount'])

plt.subplot(122)
train['LoanAmount'].plot.box(figsize=(16,5))

# %%
Gender = pd.crosstab(train['Gender'],train['Loan_Status'])
Gender

# %%
Gender.sum(axis=1).astype(float)

# %%
Gender.div(Gender.sum(axis=1).astype(float),axis=0)

# %%
(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar")

# %%
(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar",stacked=True)

# %%
from matplotlib import axes

plt.subplot(221)
(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar",stacked=True)


married = pd.crosstab(train['Married'],train['Loan_Status'])
plt.subplot(222)
(married.div(married.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True)


dependents = pd.crosstab(train['Dependents'],train['Loan_Status'])
plt.subplot(223)
(dependents.div(dependents.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True)


education = pd.crosstab(train['Education'],train['Loan_Status'])
plt.subplot(224)
(education.div(education.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True)

# %%
fig, ax = plt.subplots(2,2)
fig.set_size_inches(12, 10)
fig.suptitle("Loan Data Analysis")


(Gender.div(Gender.sum(axis=1).astype(float),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[0,0])


married = pd.crosstab(train['Married'],train['Loan_Status'])

(married.div(married.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[0,1])


dependents = pd.crosstab(train['Dependents'],train['Loan_Status'])

(dependents.div(dependents.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[1,0])


education = pd.crosstab(train['Education'],train['Loan_Status'])

(education.div(education.sum(axis=1),axis=0)*100).plot(kind="bar",stacked=True,ax=ax[1,1])

# %%
married = train.groupby(['Married','Loan_Status']).size().unstack()
married

# %%
# Numerical vs Target Variable

train.groupby('Loan_Status')["ApplicantIncome"].mean().plot.bar()

# %%
bins=[0,2500,4000,6000,81000]
group = ['Low','Average','High','Very High']
train['Income_bin'] = pd.cut(train['ApplicantIncome'],bins,labels=group)

# %%
train.head()

# %%
train['Income_bin'].value_counts().plot.bar()

# %%
Income_bin = pd.crosstab(train['Income_bin'],train['Loan_Status'])
Income_bin = (Income_bin.div(Income_bin.sum(1),axis=0)*100).plot(kind="bar",stacked=True)

Income_bin

# %%
bins = [0,1000,2000,3000,42000]
groups = ['low','medium','high','very high']

train['coApplicantBin'] = pd.cut(train['CoapplicantIncome'],bins,labels=groups)


coApplicantBin = train.groupby([train['coApplicantBin'],train['Loan_Status']]).size().unstack()

coApplicantBin = coApplicantBin.div(coApplicantBin.sum(1).astype(float),axis=0)*100

coApplicantBin

coApplicantBin.plot.bar(stacked=True)

# %%
train["total_Income"] = train['ApplicantIncome'] + train['CoapplicantIncome']
bins = [0,2500,4000,6000,81000]
group1 = ['low','medium','high','very high']

train['total_Income_bin'] = pd.cut(train['total_Income'],bins,labels=group1)

train.head()



total_Income_bin = pd.crosstab(train['total_Income_bin'],train['Loan_Status'])


# total_Income_bin.div(total_Income_bin.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True)

total_Income_bin = total_Income_bin.div(total_Income_bin.sum(1).astype(float),axis=0)*100

total_Income_bin


total_Income_bin.plot(kind="bar",stacked=True)

# %%
train.head()

# %%
bins = [0,100,200,700]
groups = ['low','average','high']

train['LoanAmount_bin'] = pd.cut(train['LoanAmount'],bins,labels=groups)

LoanAmount_bin = pd.crosstab(train['LoanAmount_bin'],train['Loan_Status'])

LoanAmount_bin.div(LoanAmount_bin.sum(1).astype(float),axis=0).plot(kind="bar",stacked=True)

# %%
train = train.drop(columns=['total_Income','LoanAmount_bin'])

# %%
train.head()

# %%
# train['Dependents'].replace("3+",3,inplace=True)
# test['Dependents'].replace("3+",3,inplace=True)

# train["Loan_Status"].replace('N',0,inplace=True)
# train["Loan_Status"].replace('Y',1,inplace=True)


# train["Gender"].replace('Male',1,inplace=True)
# train["Gender"].replace('Female',0,inplace=True)

# train['Married'].replace('Yes',1,inplace=True)
# train['Married'].replace('No',0,inplace=True)

# train['Education'].replace('Graduate',1,inplace=True)
# train['Education'].replace('Not Graduate',0,inplace=True)


# train["Property_Area"].replace("Urban",1,inplace=True)
# train["Property_Area"].replace("Rural",0,inplace=True)
# train["Property_Area"].replace("Semiurban",2,inplace=True)


# train["Self_Employed"].replace("Yes",1,inplace=True)
# train["Self_Employed"].replace("No",0,inplace=True)

# %%
train = train.drop('Loan_ID',axis=1)

# %%
train = train.drop(columns=['coApplicantBin','Income_bin',"total_Income_bin"])

# %%
train.head()

# %%
train.info()

# %%
# train['Gender'].fillna()

list = train.select_dtypes(include=['object','category']).columns

list

# %%
train['Gender'].fillna(train['Gender'].mode()[0],inplace=True)
train['Married'].fillna(train['Married'].mode()[0],inplace=True)
train['Dependents'].fillna(train['Dependents'].mode()[0],inplace=True)
train['Self_Employed'].fillna(train['Self_Employed'].mode()[0],inplace=True)
train['Credit_History'].fillna(train['Credit_History'].mode()[0],inplace=True)

train['Loan_Amount_Term'].fillna(train['Loan_Amount_Term'].mode()[0],inplace=True)

train['LoanAmount'].fillna(train['LoanAmount'].median(),inplace=True)




test['Credit_History'].fillna(test['Credit_History'].mode()[0],inplace=True)

test['Loan_Amount_Term'].fillna(test['Loan_Amount_Term'].mode()[0],inplace=True)

test['LoanAmount'].fillna(test['LoanAmount'].median(),inplace=True)

# %%
# mat = train.corr().style.background_gradient(cmap='coolwarm')

mat = train.corr()

# mat
fig, ax = plt.subplots(figsize=(9,6))
sns.heatmap(mat,vmax= .8, square = True, cmap = "BuPu")

# %%
train['LoanAmount'].plot.box()

# %%
train.describe()

# %%
IQ1 = train['LoanAmount']

IQ1.quantile(0.25)

# %%
IQ1 = train['LoanAmount'].quantile(0.25)
IQ3 = train['LoanAmount'].quantile(0.75)

IQR = IQ3 - IQ1

lower_bound = IQ1 - 1.5 * IQR
upper_bound = IQ3 + 1.5 * IQR

# upper_bound

outliers = train[(train['LoanAmount'] < lower_bound ) | (train['LoanAmount'] > upper_bound)]

outliers['LoanAmount'].to_list()

# %%
# df = pd.Series([1,2,3,4,5,1000])

# df = df.clip(1,5)

# df

# %%
# from scipy import stats

# df = pd.Series([1,2,3,4,1000])

# z_score = stats.zscore(df)


# z_score

# %%
train['LoanAmount_log'] = np.log(train['LoanAmount'])
test['LoanAmount_log'] = np.log(test['LoanAmount'])


train['LoanAmount_log'].hist(bins=20)

test['LoanAmount_log'].fillna(test['LoanAmount_log'].mode()[0],inplace=True)

# %%
# train['Dependents'].replace("3+",3,inplace=True)
# test['Dependents'].replace("3+",3,inplace=True)

# train["Loan_Status"].replace('N',0,inplace=True)
# train["Loan_Status"].replace('Y',1,inplace=True)


# train["Gender"].replace('Male',1,inplace=True)
# train["Gender"].replace('Female',0,inplace=True)

# train['Married'].replace('Yes',1,inplace=True)
# train['Married'].replace('No',0,inplace=True)

# train['Education'].replace('Graduate',1,inplace=True)
# train['Education'].replace('Not Graduate',0,inplace=True)


# train["Property_Area"].replace("Urban",1,inplace=True)
# train["Property_Area"].replace("Rural",0,inplace=True)
# train["Property_Area"].replace("Semiurban",2,inplace=True)


# train["Self_Employed"].replace("Yes",1,inplace=True)
# train["Self_Employed"].replace("No",0,inplace=True)

# %%
# train = train.drop('Loan_ID',axis=1)
test = test.drop('Loan_ID',axis=1)

# %%
# Let's build the ML Model
X = train.drop('Loan_Status',axis=1)

y = train.Loan_Status

# %%
X.info()

# %%
pd.DataFrame(X).to_csv('/content/drive/MyDrive/Colab Notebooks/Loan Prediction /train_data.csv',index=False)

# %%
nTrain = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Loan Prediction /train_data.csv')



nTrain.info()

# %%
cat_cols = train.select_dtypes(exclude=['float','int']).columns


for col in cat_cols:
  train[col] = train[col].astype('category')

# %%
train.head(5)

# %%
train.info()

# %%
X = pd.get_dummies(X,dtype='int64')
train = pd.get_dummies(train,dtype='int')
test = pd.get_dummies(test)

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay

# %%
xtrain,xval,ytrain,yval = train_test_split(X,y,test_size=0.3)

lr_model = LogisticRegression()
lr_model.fit(xtrain,ytrain)

LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True, intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1, penalty='12', random_state=1, solver='liblinear', tol=0.0001, verbose=0, warm_start = False)

# %%
ypre = lr_model.predict(xval)

# %%
# disp = ConfusionMatrixDisplay(confusion_matrix=score)
# disp.plot()

# %%
test_pre = lr_model.predict(test)

test_pre

# %%
sub = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Loan Prediction /sample_submission_49d68Cx.csv')

sub['Loan_Status'] = test_pre
sub['Loan_ID'] = test_cp.Loan_ID



sub

# %%
sub['Loan_Status'].replace('Y',1,inplace=True)
sub['Loan_Status'].replace('N',0,inplace=True)

sub.head()

# %%
pd.DataFrame(sub,columns=['Loan_ID','Loan_Status']).to_csv('/content/drive/MyDrive/Colab Notebooks/Loan Prediction /logistic.csv',index=False)

# %%
import os
os.listdir('/content/drive/MyDrive/Colab Notebooks/Loan Prediction /')

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn import metrics


sk = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
i= 1
model = LogisticRegression(random_state=1)

for trainIdx,testIdx in sk.split(X,y):
  xtrain,xtest = X.iloc[trainIdx],X.iloc[testIdx]
  ytrain,ytest = y.iloc[trainIdx], y.iloc[testIdx]

  print(" \n{} of k fold of {}".format(i,sk.n_splits))

  model.fit(xtrain,ytrain)

  ypre = model.predict(xtest)

  score = accuracy_score(ytest,ypre)

  print('Accuracy : ',score)

  i+=1

# %%
  ypred = model.predict_proba(xtest)[:,1]

  fpr, tpr, _ = metrics.roc_curve(ytest,ypred,pos_label='Y')

  auc = metrics.roc_auc_score(ytest,ypred)

  # plt.plot(fpt,tpt,lable="AUC= "+str(auc))

  # plt.figure(figsize=(12,8))

  plt.plot(fpr, tpr, label="AUC=" + str(auc))

  plt.xlabel("False Positive Rate")
  plt.ylabel("True Positive Rate")

  plt.legend(loc=4)

  plt.show()

# %%
nTrain['total_income'] = nTrain['ApplicantIncome'] + nTrain['CoapplicantIncome']
test['total_income'] = test['ApplicantIncome'] + test['CoapplicantIncome']


sns.displot(nTrain['total_income'])

# %%
nTrain['total_income_log'] = np.log(nTrain['total_income'])
test['total_Income_log'] = np.log(test['total_income'])

sns.displot(nTrain['total_income_log'])

# %%
nTrain['EMI'] = nTrain['LoanAmount']/nTrain['Loan_Amount_Term']
test['EMI'] = test['LoanAmount'] / test['Loan_Amount_Term']

sns.displot(nTrain['EMI'])

# %%
nTrain = nTrain.drop(columns=['CoapplicantIncome','ApplicantIncome','Loan_Amount_Term','LoanAmount'])

test = test.drop(columns=['CoapplicantIncome','ApplicantIncome','Loan_Amount_Term','LoanAmount'])

# %%
nTrain.info()

# %%
nTrain['Balance_Income'] = nTrain['total_income'] - (nTrain['EMI'] * 1000)
test['Balance_Income'] = test['total_income'] - (test['EMI'] * 1000)

# %%
test.info()

# %%
nTrain = pd.get_dummies(nTrain)

# %%
X = nTrain

y = train_cp.Loan_Status

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

sk = StratifiedKFold(n_splits=5, random_state=1, shuffle=True)
i= 1
# model = LogisticRegression(random_state=1)

# model = tree.DecisionTreeClassifier(random_state=1)



for trainIdx,testIdx in sk.split(X,y):
  xtrain,xtest = X.iloc[trainIdx],X.iloc[testIdx]
  ytrain,ytest = y.iloc[trainIdx], y.iloc[testIdx]

  print(" \n{} of k fold of {}".format(i,sk.n_splits))

  model.fit(xtrain,ytrain)

  ypre = model.predict(xtest)

  score = accuracy_score(ytest,ypre)

  print('Accuracy : ',score)

  i+=1

# %%
# from sklearn.model_selection import GridSearchCV


# params = {
#     'n_estimators': [x for x in range(1,20,2)],
#     'max_depth': [x for x in range(1,200,20)]
# }

# # gdSearch = GridSearchCV(RandomForestClassifier(random_state=1,max_depth=10), params)

# xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size = 0.3)

# gdSearch.fit(xtrain,ytrain)



# model = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini', max_depth=None, max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0, min_impurity_split=None, min_samples_leaf= 1, min_samples_split=2, min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1, oob_score=False, random_state=1, verbose=0, warm_start=False)
# grid_model = GridSearchCV(cv=None, error_score='raise', estimator= model, fit_params=None, iid=True, n_jobs=1,param_grid=params,pre_dispatch='2*n_jbos', refit=True, retur_train_score='warn',scoring=None, verbose=0)



from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split

# Parameter grid
params = {
    'n_estimators': [x for x in range(1, 20, 2)],
    'max_depth': [x for x in range(1, 200, 20)]
}

# Train-test split
xtrain, xtest, ytrain, ytest = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=1
)

# Base model
model = RandomForestClassifier(random_state=1)

# Grid Search
gridSearch = GridSearchCV(
    estimator=model,
    param_grid=params,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit
gridSearch.fit(xtrain, ytrain)

# Best parameters
print(gridSearch.best_params_)

# Best score
print(gridSearch.best_score_)

# %%
i =1
model = RandomForestClassifier(max_depth=3, n_estimators = 41, random_state=1)

for trainIdx,testIdx in sk.split(X,y):
  xtrain,xtest = X.iloc[trainIdx],X.iloc[testIdx]
  ytrain,ytest = y.iloc[trainIdx], y.iloc[testIdx]

  print(" \n{} of k fold of {}".format(i,sk.n_splits))

  model.fit(xtrain,ytrain)

  ypre = model.predict(xtest)

  score = accuracy_score(ytest,ypre)

  print('Accuracy : ',score)

  i+=1

# %%
imp = model.feature_importances_
imp

for x,y in zip(X.columns,imp):
  print(x,y)

# %%
# importance = model.feature_importances_

imp = pd.Series(model.feature_importances_,index=X.columns)

imp.plot(kind='barh')
